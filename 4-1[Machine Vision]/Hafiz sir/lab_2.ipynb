# %%
# %matplotlib inline

# %% [markdown]
# # Image Histogram

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img = cv2.imread('image.png', -1)
# gray_image = cv2.imread('example.jpg', cv2.)
plt.imshow(img)

# %%
img = cv2.imread('image.png', 0)
# gray_image = cv2.imread('example.jpg', cv2.)
plt.imshow(img)

# %%
img = cv2.imread('image.png', 1)
# gray_image = cv2.imread('example.jpg', cv2.)
plt.imshow(img)
